# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categories = ['Food', 'Travel', 'Fashion', 'Fitness', 'Music', 'Culture', 'Family', 'Health']

# Number of data entries
data_size = 500

# Generate the data dictionary
data = {
    'Date': pd.date_range('2021-01-01', periods=data_size),
    'Category': [random.choice(categories) for _ in range(data_size)],
    'Likes': np.random.randint(0, 10000, size=data_size)
}

df = pd.DataFrame(data)

df.head(10)
# Out:
#         Date Category  Likes
# 0 2021-01-01   Travel   9669
# 1 2021-01-02   Family   3594
# 2 2021-01-03   Health     95
# 3 2021-01-04   Family   3229
# 4 2021-01-05   Health   2686
# 5 2021-01-06     Food   2591
# 6 2021-01-07   Health   7282
# 7 2021-01-08   Family   4634
# 8 2021-01-09     Food   3633
# 9 2021-01-10   Family   8746

# %% [markdown]
# ### Print the count of each category

# %%
df["Category"].value_counts()
# Out:
# Health     77
# Food       77
# Fashion    66
# Music      63
# Fitness    60
# Travel     59
# Family     49
# Culture    49
# Name: Category, dtype: int64

# %% [markdown]
# ### Identify duplicated data

# %%
duplicates = df[df.duplicated()]
len(duplicates)
# Out:
# 0

# %%
df["Month"] = df["Date"].dt.month
df["Day_week"] = df["Date"].dt.day_name()
df["Year"] = df["Date"].dt.year

# %%
df
# Out:
#           Date Category  Likes  Month   Day_week  Year
# 0   2021-01-01   Travel   9669      1     Friday  2021
# 1   2021-01-02   Family   3594      1   Saturday  2021
# 2   2021-01-03   Health     95      1     Sunday  2021
# 3   2021-01-04   Family   3229      1     Monday  2021
# 4   2021-01-05   Health   2686      1    Tuesday  2021
# ..         ...      ...    ...    ...        ...   ...
# 495 2022-05-11  Fashion   8809      5  Wednesday  2022
# 496 2022-05-12     Food    617      5   Thursday  2022
# 497 2022-05-13   Health   3905      5     Friday  2022
# 498 2022-05-14     Food   3880      5   Saturday  2022
# 499 2022-05-15   Family   6977      5     Sunday  2022
#
# [500 rows x 6 columns]

# %%
df.dtypes
# Out:
# Date        datetime64[ns]
# Category            object
# Likes                int64
# Month                int64
# Day_week            object
# Year                 int64
# dtype: object

# %% [markdown]
# # Visualisations

# %%
plt.figure(figsize = (10,5))

plt.scatter(df["Category"], df["Likes"])

# %%
df.columns
# Out:
# Index(['Date', 'Category', 'Likes', 'Month', 'Day_week', 'Year'], dtype='object')

# %% [markdown]
# # Category-Wise Engagement Analysis
#
# Calculate the average and total likes per category to see which categories of posts drive the most engagement. This can help identify popular content types.

# %%
category_likes = df.groupby("Category")["Likes"].sum().reset_index()

plt.figure(figsize = (10,5))
sns.barplot(x = "Category" , y = "Likes", data = category_likes)
plt.title("Category vs Likes")
plt.xlabel("Category")
plt.ylabel("Total Likes")
# Out:
# Text(0, 0.5, 'Total Likes')

# %% [markdown]
# # Day of the Week Analysis
# Analyze engagement (likes) by day of the week to understand which days see higher user interaction. This can inform the best days to post for maximum reach.

# %%
likes_per_day = df.groupby("Day_week")["Likes"].sum().reset_index()

plt.figure(figsize = (8,8))

plt.pie(likes_per_day["Likes"], labels = likes_per_day["Day_week"], autopct = "%1.1f%%")
plt.title("Day vs Likes")
# Out:
# Text(0.5, 1.0, 'Day vs Likes')

# %%
monthly_likes = df.groupby(["Year", "Month"])["Likes"].sum().reset_index()

# %%
Monthly_likes
# Out:
#     Year  Month   Likes
# 0   2021      1  142830
# 1   2021      2  144291
# 2   2021      3  132342
# 3   2021      4  134796
# 4   2021      5  155615
# 5   2021      6  129474
# 6   2021      7  157885
# 7   2021      8  147993
# 8   2021      9  150474
# 9   2021     10  150373
# 10  2021     11  126722
# 11  2021     12  165492
# 12  2022      1  171248
# 13  2022      2  154150
# 14  2022      3  126255
# 15  2022      4  141539
# 16  2022      5   67834

# %%
monthly_likes['MoM_Growth'] = monthly_likes['Likes'].pct_change() * 100  # Convert to percentage

print(monthly_likes)
# Out:
#     Year  Month   Likes  MoM_Growth
# 0   2021      1  142830         NaN
# 1   2021      2  144291    1.022894
# 2   2021      3  132342   -8.281182
# 3   2021      4  134796    1.854287
# 4   2021      5  155615   15.444820
# 5   2021      6  129474  -16.798509
# 6   2021      7  157885   21.943402
# 7   2021      8  147993   -6.265320
# 8   2021      9  150474    1.676431
# 9   2021     10  150373   -0.067121
# 10  2021     11  126722  -15.728222
# 11  2021     12  165492   30.594530
# 12  2022      1  171248    3.478114
# 13  2022      2  154150   -9.984350
# 14  2022      3  126255  -18.096010
# 15  2022      4  141539   12.105659
# 16  2022      5   67834  -52.073987

# %%
# Bar plot for Month-over-Month Growth Rate
plt.figure(figsize=(12, 6))
plt.bar(monthly_likes.index, monthly_likes['MoM_Growth'], color='skyblue')
plt.title("Month-over-Month Growth Rate of Likes")
plt.xlabel("Time (Ordered by Year and Month)")
plt.ylabel("Growth Rate (%)")
plt.xticks(ticks=monthly_likes.index, labels=[f"{int(y)}-{int(m):02}" for y, m in zip(monthly_likes['Year'], monthly_likes['Month'])], rotation=45)
plt.tight_layout()
plt.show()
